# %% [markdown]
# # `ecg_00.jpynb`: Read and plot ECG data
#
# In this Jupyter notebook, we read and plot ECG data from a healthy subject.

# %% [markdown]
# ## 1. Open an ECG file into the `ecg` variable
# We want to read the file `ECGu.txt` from the `data` folder.
# We shall put the data into a variable named `ecg`.

# %% [markdown]
# ### 1.1. Define the path to the ECG file
#
# The path to the file is `data/ECGu.txt`, starting from the root of the project.
# However, the present notebook is located in the `notebooks` folder, so we need to go up one level to reach the `data` folder:
#   1. go up one level: `../`
#   1. then, reach the `data` folder: `../data/`
#   1. then, reach the file: `../data/ECGu.txt`

# %%
fNameECG = r'C:\Users\SCD UM\OneDrive\Documents\Cours M2 2024-2025\S1\Santé Activité Physique\MOTTET\Exo_ECG\ECGu.txt'

# %% [markdown]
# However, if we `%run` this notebook from another notebook, the path is expected from the other notebook. So we need a way to define the path to the file in a way that is independent of the notebook that is running the present notebook.

# %%
# if the present working directory is the directory of this file, change the path to the project root
import os
if os.getcwd().endswith("notebooks"):
    os.chdir("..")

fNameECG = r'C:\Users\SCD UM\OneDrive\Documents\Cours M2 2024-2025\S1\Santé Activité Physique\MOTTET\Exo_ECG\ECGu.txt'

# %% [markdown]
# ### 1.2. Read the ecg file

# %%
import numpy as np 

ecg = np.genfromtxt(fNameECG, delimiter=' ')

# %% [markdown]
# # 2. Plot the content of the `egc` variable

# %%
import matplotlib.pyplot as plt 

# Sampling frequency
Fe = 1024  

# ADC Gain
Gain_ADC = 520e-6  

# Converting ECGs to mV taking gain into account
ecg_mV = ecg * (Gain_ADC * 1000) 

# Creation of the time axis
time_axis = [i / Fe for i in range(len(ecg_mV))]

# ECG tracing
plt.plot(time_axis, ecg_mV, label='Leads (mV)')
plt.xlabel('Time (s)')
plt.ylabel('Leads (mV)')
plt.title('ECG')
plt.show()

print("ecg_00.ipynb finished")
# Out:
# ecg_00.ipynb finished

# %%
import pandas as pd

# Creation of a dataframe
ECG = pd.read_csv (fNameECG, sep=" ")
print(ECG)
# Out:
#       -275.0\t  -119.0\t  -119.0\t.1  Unnamed: 3
# 0       -275.0    -119.0      -119.0         NaN
# 1       -275.0    -118.0      -121.0         NaN
# 2       -275.0    -121.0      -112.0         NaN
# 3       -273.0    -120.0      -105.0         NaN
# 4       -274.0    -124.0      -101.0         NaN
# ...        ...       ...         ...         ...
# 6494       3.0     -92.0        28.0         NaN
# 6495       1.0     -86.0        22.0         NaN
# 6496      -4.0     -83.0        21.0         NaN
# 6497      -9.0     -88.0        31.0         NaN
# 6498     -16.0     -96.0        33.0         NaN
#
# [6499 rows x 4 columns]

# %%
ECG.columns= ['I', 'II', 'III', 'IV']
print(ECG)
# Out:
#           I     II    III  IV
# 0    -275.0 -119.0 -119.0 NaN
# 1    -275.0 -118.0 -121.0 NaN
# 2    -275.0 -121.0 -112.0 NaN
# 3    -273.0 -120.0 -105.0 NaN
# 4    -274.0 -124.0 -101.0 NaN
# ...     ...    ...    ...  ..
# 6494    3.0  -92.0   28.0 NaN
# 6495    1.0  -86.0   22.0 NaN
# 6496   -4.0  -83.0   21.0 NaN
# 6497   -9.0  -88.0   31.0 NaN
# 6498  -16.0  -96.0   33.0 NaN
#
# [6499 rows x 4 columns]

# %%
ecg = ECG.drop("IV", axis=1)

# %%
print(ecg)
# Out:
#           I     II    III
# 0    -275.0 -119.0 -119.0
# 1    -275.0 -118.0 -121.0
# 2    -275.0 -121.0 -112.0
# 3    -273.0 -120.0 -105.0
# 4    -274.0 -124.0 -101.0
# ...     ...    ...    ...
# 6494    3.0  -92.0   28.0
# 6495    1.0  -86.0   22.0
# 6496   -4.0  -83.0   21.0
# 6497   -9.0  -88.0   31.0
# 6498  -16.0  -96.0   33.0
#
# [6499 rows x 3 columns]

# %%
ecg_I = ecg[['I']]
ecg_II = ecg[['II']]
ecg_III = ecg[['III']]
print(ecg_I)
# Out:
#           I
# 0    -275.0
# 1    -275.0
# 2    -275.0
# 3    -273.0
# 4    -274.0
# ...     ...
# 6494    3.0
# 6495    1.0
# 6496   -4.0
# 6497   -9.0
# 6498  -16.0
#
# [6499 rows x 1 columns]

# %%
import matplotlib.pyplot as plt 

# Sampling frequency 
Fe = 1024  

# ADC Gain
Gain_ADC = 520e-6  

# Creation of the time axis
time_axis = [i / Fe for i in range(len(ecg_I_mV))]

# Converting ECG to mv taking gain into account
ecg_I_mV = ecg_I * (Gain_ADC * 1000)
ecg_II_mV = ecg_II * (Gain_ADC * 1000)
ecg_III_mV = ecg_III * (Gain_ADC * 1000)


# ECG I tracing
plt.plot(time_axis, ecg_I_mV, label='Lead I (mV)')
plt.xlabel('Time (s)')
plt.ylabel('Lead I (mV)')
plt.title('ECG I')
plt.show()

# ECG II tracing
plt.plot(time_axis, ecg_II_mV, label='Lead II (mV)')
plt.xlabel('Time (s)')
plt.ylabel('Lead II (mV)')
plt.title('ECG II')
plt.show()

# ECG III tracing
plt.plot(time_axis, ecg_III_mV, label='Lead III (mV)')
plt.xlabel('Time (s)')
plt.ylabel('Lead III (mV)')
plt.title('ECG III')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sparse
from scipy.sparse.linalg import splu

# Sampling frequency  
Fe = 1024  

# ADC Gain
Gain_ADC = 520e-6  

# Convertion ECG I to mVs taking account of gain
ecg_I_mV = ecg_I * (Gain_ADC * 1000)

# If ecg_I_mV is a dataframe, it'll be converted to numpy
if isinstance(ecg_I_mV, pd.DataFrame):
    ecg_I_mV = ecg_I_mV.to_numpy()  

# Creation of the time axis
time_axis = [i / Fe for i in range(len(ecg_I_mV))]

# Using Whittaker-Eilers as a low-pass filter
# Definition of the sparse difference function
def speyediff(N, d, format='csc'):
    assert not (d < 0), "d must be non negative"
    shape = (N-d, N)
    diagonals = np.zeros(2*d + 1)
    diagonals[d] = 1.
    for i in range(d):
        diff = diagonals[:-1] - diagonals[1:]
        diagonals = diff
    offsets = np.arange(d+1)
    spmat = sparse.diags(diagonals, offsets, shape, format=format)
    return spmat

# Definition of the Whittaker-Eiler smoothing function
def whittaker_smooth(y, lmbd, d=2):
    m = len(y)
    E = sparse.eye(m, format='csc')
    D = speyediff(m, d, format='csc')
    coefmat = E + lmbd * D.conj().T.dot(D)
    z = splu(coefmat).solve(y)
    return z

# Smoothing parameters
lmbd = 1000  # Desired amount of smoothing
d = 2  # Smoothing order

# Application of the smoothing function
smoothed_ecg_I = whittaker_smooth(ecg_I_mV, lmbd, d)

# ECG I - Smoothed tracing
plt.figure(figsize=(10, 6))
plt.plot(time_axis, smoothed_ecg_I, label='Données lissées', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Lead I (mV)')
plt.title('ECG I - Données lissées')
plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sparse
from scipy.sparse.linalg import splu

# Sampling frequency 
Fe = 1024  

# ADC Gain
Gain_ADC = 520e-6  

# Converting ECG II to mVs taking account of gain
ecg_II_mV = ecg_II * (Gain_ADC * 1000)

# If ecg_II_mV is a dataframe, it'll be converted to numpy
if isinstance(ecg_II_mV, pd.DataFrame):
    ecg_II_mV = ecg_II_mV.to_numpy()  

# Création de l'axe des temps
time_axis = [i / Fe for i in range(len(ecg_II_mV))]

# Using Whittaker-Eilers as a low-pass filter
# Definition of the sparse difference function
def speyediff(N, d, format='csc'):
    assert not (d < 0), "d must be non negative"
    shape = (N-d, N)
    diagonals = np.zeros(2*d + 1)
    diagonals[d] = 1.
    for i in range(d):
        diff = diagonals[:-1] - diagonals[1:]
        diagonals = diff
    offsets = np.arange(d+1)
    spmat = sparse.diags(diagonals, offsets, shape, format=format)
    return spmat

# Definition of the Whittaker-Eiler smoothing function
def whittaker_smooth(y, lmbd, d=2):
    m = len(y)
    E = sparse.eye(m, format='csc')
    D = speyediff(m, d, format='csc')
    coefmat = E + lmbd * D.conj().T.dot(D)
    z = splu(coefmat).solve(y)
    return z

# Smoothing parameters 
lmbd = 1000  # Desired amount of smoothing
d = 2  # Smoothing order

# Application of the smoothing function
smoothed_ecg_II = whittaker_smooth(ecg_II_mV, lmbd, d)

# ECG II - Smoothed tracing
plt.figure(figsize=(10, 6))
plt.plot(time_axis, smoothed_ecg_II, label='Données lissées', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Lead II (mV)')
plt.title('ECG II - Données lissées')
plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sparse
from scipy.sparse.linalg import splu

# Sampling frequency
Fe = 1024  

# ADC Gain
Gain_ADC = 520e-6  

# Converting ECG III to mV taking account of gain
ecg_III_mV = ecg_III * (Gain_ADC * 1000)

# If ecg_III_mV is a dataframe, it'll be converted to numpy
if isinstance(ecg_III_mV, pd.DataFrame):
    ecg_III_mV = ecg_III_mV.to_numpy()  # Conversion si c'est un DataFrame

# Creation of the time axis
time_axis = [i / Fe for i in range(len(ecg_III_mV))]

# Using Whittaker-Eilers as a low-pass filter
# Definition of the sparse difference function
def speyediff(N, d, format='csc'):
    assert not (d < 0), "d must be non negative"
    shape = (N-d, N)
    diagonals = np.zeros(2*d + 1)
    diagonals[d] = 1.
    for i in range(d):
        diff = diagonals[:-1] - diagonals[1:]
        diagonals = diff
    offsets = np.arange(d+1)
    spmat = sparse.diags(diagonals, offsets, shape, format=format)
    return spmat

# Definition of the Whittaker-Eiler smoothing function
def whittaker_smooth(y, lmbd, d=2):
    m = len(y)
    E = sparse.eye(m, format='csc')
    D = speyediff(m, d, format='csc')
    coefmat = E + lmbd * D.conj().T.dot(D)
    z = splu(coefmat).solve(y)
    return z

# Smoothing parameters
lmbd = 1000  # Desired amount of smoothinf
d = 2  # Smoothing order

# Application of the smoothing function
smoothed_ecg_III = whittaker_smooth(ecg_III_mV, lmbd, d)

# ECG III - Smoothed tracing
plt.figure(figsize=(10, 6))
plt.plot(time_axis, smoothed_ecg_III, label='Données lissées', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Lead III (mV)')
plt.title('ECG III - Données lissées')
plt.legend()

# %% [markdown]
# # 1.2.3.
# The ECG does not appear to be properly calibrated because the amplitude ranges from -600 mV to +600 mV, which is higher than the typical magnitude seen on an ECG.
#
# This is not a normal ECG as the QRS complexes appear very close together, which could indicate tachycardia.
